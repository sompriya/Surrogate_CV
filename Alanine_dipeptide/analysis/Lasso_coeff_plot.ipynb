# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lasso_tda = {'d2-19':4.2236,'d6-9':123.9035,'d6-11':74.1519,'d6-15':24.5484,
             'd6-16':20.8633,'d6-17':3.6156,'d6-19':10.3116,'d7-9':15.1608,
             'd7-11':36.7252,'d7-16':22.8718,'d7-19':8.6337,'d9-16':1.8104,
             'd11-16':5.3758,'d11-17':1.7865,'d11-19':0.6806}

a = sorted(lasso_tda.items(), key=lambda x:x[1], reverse=True)
a = dict(a)
names, counts = zip(*a.items())
plt.figure(figsize=(12,3))
plt.bar(names, counts)
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=12)
plt.ylabel('|Coefficients|',fontsize=14)
plt.title('Deep-TDA Lasso',fontsize=16)
plt.savefig('deep-tda-lasso-coeff.png',dpi=200,bbox_inches='tight')

# %%
lasso_tica = {'d2-7':2.1943,'d2-11':0.5962,'d2-19':0.2754,'d5-7':0.4293,'d5-11':0.7594,
              'd5-17':0.1269,'d5-19':1.7356,'d6-9':13.3339,'d6-11':8.7770,'d6-15':0.1922,
              'd6-16':2.5192,'d6-17':2.5143,'d7-11':3.1540,
              'd7-15':1.5354,'d7-16':1.8088,'d7-19':2.4623,'d9-16':1.7945,'d9-17':0.2039,
              'd11-16':1.0735,'d11-17':0.0421,'d16-17':1.9173,'d16-19':0.0261}

a = sorted(lasso_tica.items(), key=lambda x:x[1], reverse=True)
a = dict(a)
names, counts = zip(*a.items())
plt.figure(figsize=(12,3))
plt.bar(names, counts)
plt.xticks(fontsize=12,rotation=45)
plt.yticks(fontsize=12)
plt.xlabel('Descriptors',fontsize=14)
plt.ylabel('|Coefficients|',fontsize=14)
plt.title('Deep-TICA Lasso',fontsize=16)
plt.savefig('deep-tica-lasso-coeff.png',dpi=200,bbox_inches='tight')
